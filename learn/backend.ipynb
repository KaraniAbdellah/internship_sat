# %%
# Fast Api is ASGI --> Asynchrone Server Gateway Interface
# and Fast Api comes with some programs in this server like uvicorn, ...
# for run fastapi we can run just UVICORN
# --> pip install "uvicorn[standard]"
# --> uvicorn main:app
    # file name if main and app is class name
